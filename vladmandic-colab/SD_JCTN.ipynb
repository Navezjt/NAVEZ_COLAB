# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/Navezjt/NAVEZ_COLAB/blob/main/vladmandic-colab/SD_JCTN.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# # <img src="https://avatars.githubusercontent.com/u/110367357?s=400&u=a533e385e1d0ce56331e903f1c2ff02d74f91c29&v=4" width="30"/> **InvDudes's Vladmanidc Colab Remastered**
# ---
#
# Me: ![Discord](https://dcbadge.vercel.app/api/shield/41367898021494784?style=flat)
#
# YET another Colab for Stable Diffusion. This time it's for Vladmandic's fork. Heavily based upon NoCrypt's Cola, but without using a zip file to install UI.

# %%
#@title 1.Vladmandic SD インストール

#ドライブをマウント
Mount_Drive = False # @param {type: "boolean"}

if Mount_Drive:
    import os
    from google.colab import drive
    if not os.path.exists("/content/drive"):
        drive.mount("/content/drive")
# !apt -y update -qq
# !apt -y install -qq aria2
# !pip install rembg
# !aria2c --optimize-concurrent-downloads --console-log-level=error --summary-interval=10 -j5 -x16 -s16 -k1M -c -d {dst} -Z {parsed_link}
# !pip install -U xformers
#!pip install -q torch==2.0.0+cu118 torchvision==0.15.1+cu118 torchaudio==2.0.1+cu118 torchtext==0.15.1 torchdata==0.6.0 --extra-index-url https://download.pytorch.org/whl/cu118 -U
#!pip install -q xformers==0.0.18 triton==2.0.0 -U
# %cd /content

# !git clone https://github.com/Navezjt/automatic
# Out:
# 16 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: https://cloud.r-project.org/bin/linux/ubuntu/jammy-cran40/InRelease: Key is stored in legacy trusted.gpg keyring (/etc/apt/trusted.gpg), see the DEPRECATION section in apt-key(8) for details.
# The following additional packages will be installed:
#   libaria2-0 libc-ares2
# The following NEW packages will be installed:
#   aria2 libaria2-0 libc-ares2
# 0 upgraded, 3 newly installed, 0 to remove and 16 not upgraded.
# Need to get 1,513 kB of archives.
# After this operation, 5,441 kB of additional disk space will be used.
# Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 120509 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.18.1-1ubuntu0.22.04.2_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.2) ...
# Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.36.0-1_amd64.deb ...
# Unpacking libaria2-0:amd64 (1.36.0-1) ...
# Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.36.0-1_amd64.deb ...
# Unpacking aria2 (1.36.0-1) ...
# Setting up libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.2) ...
# Setting up libaria2-0:amd64 (1.36.0-1) ...
# Setting up aria2 (1.36.0-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.1) ...
# Collecting rembg
#   Downloading rembg-2.0.50-py3-none-any.whl (26 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rembg) (1.22.4)
# Collecting onnxruntime (from rembg)
#   Downloading onnxruntime-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (from rembg) (4.8.0.74)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from rembg) (8.4.0)
# Requirement already satisfied: pooch in /usr/local/lib/python3.10/dist-packages (from rembg) (1.6.0)
# Collecting pymatting (from rembg)
#   Downloading PyMatting-1.1.8-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from rembg) (0.19.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from rembg) (1.10.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from rembg) (4.65.0)
# Collecting coloredlogs (from onnxruntime->rembg)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime->rembg) (23.5.26)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from onnxruntime->rembg) (23.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime->rembg) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime->rembg) (1.11.1)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from pooch->rembg) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch->rembg) (2.27.1)
# Requirement already satisfied: numba!=0.49.0 in /usr/local/lib/python3.10/dist-packages (from pymatting->rembg) (0.56.4)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->rembg) (3.1)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->rembg) (2.25.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->rembg) (2023.7.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->rembg) (1.4.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba!=0.49.0->pymatting->rembg) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba!=0.49.0->pymatting->rembg) (67.7.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch->rembg) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch->rembg) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch->rembg) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch->rembg) (3.4)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime->rembg)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime->rembg) (1.3.0)
# Installing collected packages: humanfriendly, pymatting, coloredlogs, onnxruntime, rembg
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 onnxruntime-1.15.1 pymatting-1.1.8 rembg-2.0.50
# Exception caught
# Exception: [download_helper.cc:451] errorCode=1 Unrecognized URI or unsupported protocol: {parsed_link}
#
# Collecting xformers
#   Downloading xformers-0.0.20-cp310-cp310-manylinux2014_x86_64.whl (109.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.1/109.1 MB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xformers) (1.22.4)
# Collecting pyre-extensions==0.0.29 (from xformers)
#   Downloading pyre_extensions-0.0.29-py3-none-any.whl (12 kB)
# Requirement already satisfied: torch==2.0.1 in /usr/local/lib/python3.10/dist-packages (from xformers) (2.0.1+cu118)
# Collecting typing-inspect (from pyre-extensions==0.0.29->xformers)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pyre-extensions==0.0.29->xformers) (4.7.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->xformers) (3.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->xformers) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->xformers) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->xformers) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->xformers) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.1->xformers) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.1->xformers) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.0.1->xformers) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.0.1->xformers) (1.3.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect->pyre-extensions==0.0.29->xformers)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: mypy-extensions, typing-inspect, pyre-extensions, xformers
# Successfully installed mypy-extensions-1.0.0 pyre-extensions-0.0.29 typing-inspect-0.9.0 xformers-0.0.20
# /content
# Cloning into 'automatic'...
# remote: Enumerating objects: 21448, done.
# remote: Counting objects: 100% (300/300), done.
# remote: Compressing objects: 100% (267/267), done.
# remote: Total 21448 (delta 28), reused 276 (delta 23), pack-reused 21148
# Receiving objects: 100% (21448/21448), 27.89 MiB | 34.44 MiB/s, done.
# Resolving deltas: 100% (15516/15516), done.

# %%
#@title  2.モデル選択

import os

model_name ="7th_anime_v3_A" #@param ["stable_diffusion_v1.5","stable_diffusion_v2.1","waifu_diffusion_v1.3","Openjourney","anything-v3.0","anything-v4.0","anything-v4.5","Counterfeit-V2.0","Counterfeit-V2.5","8528-diffusion","AbyssOrangeMix2","EerieOrangeMix2","trinart2_step115000","Eimis_Anime_Diffusion_1.0v","dreamlike-photoreal-2.0","Cyberpunk-Anime-Diffusion","Plat_Diffusion_v1.3.1","ACertainThing","pastel_mix","Basil_mix_fixed","Realistic_Vision_V1.3","SukiyakiMix-v1.0","7th_anime_v1.1", "7th_anime_v2_A", "7th_anime_v2_B", "7th_anime_v2_C", "7th_anime_v2_G","7th_anime_v3_A", "7th_anime_v3_B", "7th_anime_v3_C","7th_anime_3.1_B","YuzuGinger_v4","YuzuLemonMilk_v1.5", "Defmix-v1.1","RDtMix","meadmix","Nabylon-v1.0","LonganMix","Corneo's_7th_Heaven_Mix", "Corneo's_Shinra26_Mix","atwmix_test2","Graham_Special", "BalorV2featAbyssOrange2","Balor-V2.5featAOM3A3","ChilloutMix", "wd-1-5-beta2","AniReality-Mix"] {allow-input: false}

model_dict={
    "stable_diffusion_v1.5":"https://huggingface.co/camenduru/sd15/resolve/main/v1-5-pruned-emaonly.ckpt",
    "stable_diffusion_v2.1":"https://huggingface.co/stabilityai/stable-diffusion-2-1/resolve/main/v2-1_768-ema-pruned.ckpt",
    "waifu_diffusion_v1.3":"https://huggingface.co/hakurei/waifu-diffusion-v1-3/resolve/main/wd-v1-3-float32.ckpt",
    "Openjourney":"https://huggingface.co/prompthero/openjourney/resolve/main/mdjrny-v4.safetensors",
    "anything-v3.0":"https://huggingface.co/Linaqruf/anything-v3.0/resolve/main/anything-v3-fp32-pruned.safetensors",
    "anything-v4.0":"https://huggingface.co/andite/anything-v4.0/resolve/main/anything-v4.0-pruned.ckpt",
    "anything-v4.5":"https://huggingface.co/andite/anything-v4.0/resolve/main/anything-v4.5-pruned.safetensors",
    "Counterfeit-V2.0":"https://huggingface.co/gsdf/Counterfeit-V2.0/resolve/main/Counterfeit-V2.0fp16.safetensors",
    "Counterfeit-V2.5":"https://huggingface.co/gsdf/Counterfeit-V2.5/resolve/main/Counterfeit-V2.5_pruned.safetensors",
    "8528-diffusion":"https://huggingface.co/852wa/8528-diffusion/resolve/main/8528d-final.ckpt",
    "AbyssOrangeMix2":"https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/Models/AbyssOrangeMix2/AbyssOrangeMix2_nsfw.safetensors",
    "EerieOrangeMix2":"https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/Models/EerieOrangeMix/EerieOrangeMix2.safetensors",
    "trinart2_step115000":"https://huggingface.co/naclbit/trinart_stable_diffusion_v2/resolve/main/trinart2_step115000.ckpt",
    "EimisAnimeDiffusion_1.0v":"https://huggingface.co/eimiss/EimisAnimeDiffusion_1.0v/resolve/main/EimisAnimeDiffusion_1-0v.ckpt",
    "dreamlike-photoreal-2.0":"https://huggingface.co/dreamlike-art/dreamlike-photoreal-2.0/resolve/main/dreamlike-photoreal-2.0.safetensors",
    "Cyberpunk-Anime-Diffusion":"https://huggingface.co/DGSpitzer/Cyberpunk-Anime-Diffusion/resolve/main/Cyberpunk-Anime-Diffusion.ckpt",
    "Plat_Diffusion_v1.3.1":"https://huggingface.co/p1atdev/pd-archive/resolve/main/plat-v1-3-1.safetensors",
    "ACertainThing":"https://huggingface.co/JosephusCheung/ACertainThing/resolve/main/ACertainThing.ckpt",
    "pastel_mix":"https://huggingface.co/andite/pastel-mix/resolve/main/pastelmix-better-vae-fp16.safetensors",
    "Basil_mix_fixed":"https://huggingface.co/nuigurumi/basil_mix/resolve/main/Basil_mix_fixed.safetensors",
    "Realistic_Vision_V1.3":"https://civitai.com/api/download/models/6987",
    "SukiyakiMix-v1.0":"https://huggingface.co/Vsukiyaki/SukiyakiMix-v1.0/resolve/main/SukiyakiMix-v1.0-fp16.safetensors",
    "7th_anime_v1.1":"https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v1/7th_anime_v1.1.safetensors",
    "7th_anime_v2_A":"https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v2/7th_anime_v2_A.safetensors",
    "7th_anime_v2_B":"https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v2/7th_anime_v2_B.safetensors",
    "7th_anime_v2_C":"https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v2/7th_anime_v2_C.safetensors",
    "7th_anime_v2_G":"https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v2/7th_anime_v2_G.safetensors",
    "7th_anime_v3_A":"https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v3/7th_anime_v3_A.safetensors",
    "7th_anime_v3_B":"https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v3/7th_anime_v3_B.safetensors",
    "7th_anime_v3_C":"https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v3/7th_anime_v3_C.safetensors",
    "7th_anime_3.1_B":"https://huggingface.co/syaimu/7th_test/resolve/main/7th_anime_3.1_B.ckpt",
    "YuzuGinger_v4":"https://huggingface.co/thiros/YuzuLemonTea/resolve/main/YuzuGinger_v4-pruned.safetensors",
    "YuzuLemonMilk_v1.5":"https://huggingface.co/thiros/YuzuLemonTea/resolve/main/YuzuLemonMilk_v1.5-pruned.safetensors",
    "Defmix-v1.1":"https://huggingface.co/Defpoint/Defmix-v1.0/resolve/main/Defmix-v1.1.safetensors",
    "RDtMix":"https://huggingface.co/Hemlok/DateMix/resolve/main/RDtMix-fp16.safetensors",
    "meadmix":"https://huggingface.co/sazanka-imoto/MeadMix/resolve/main/meadmix.safetensors",
    "Nabylon-v1.0":"https://huggingface.co/NegiInNattoMaki/Nabylon-v1.0/resolve/main/Nabylon-v1.0-fp16.safetensors",
    "LonganMix":"https://huggingface.co/Hemlok/LonganMix/resolve/main/LonganMix-fp16.ckpt",
    "Corneo's_7th_Heaven_Mix":"https://civitai.com/api/download/models/5338",
    "Corneo's_Shinra26_Mix":"https://civitai.com/api/download/models/6918",
    "atwmix_test2":"https://huggingface.co/atsuwo/atwmix_test2/resolve/main/atwmix_test2.ckpt",
    "Graham_Special":"https://huggingface.co/Graham-san/Graham_Special/resolve/main/Graham%20Special%20v1.ckpt",
    "BalorV2featAbyssOrange2":"https://huggingface.co/ploughB660/Balor-V2/resolve/main/BalorV2featAbyssOrange2.safetensors",
    "Balor-V2.5featAOM3A3":"https://huggingface.co/ploughB660/Balor-V3/resolve/main/Balor-V2.5featAOM3A3.safetensors",
    "ChilloutMix":"https://civitai.com/api/download/models/11745",
    "wd-1-5-beta2":"https://huggingface.co/waifu-diffusion/wd-1-5-beta2/resolve/main/checkpoints/wd-1-5-beta2-aesthetic-fp16.safetensors",
    "AniReality-Mix":"https://civitai.com/api/download/models/33305"
}

model_url = model_dict.get(model_name)

def install(model_url):
    base_name = os.path.basename(model_url)
    if model_url.startswith("https://drive.google.com"):
        os.chdir("/content/models")
        # !gdown --fuzzy {model_url}
    elif model_url.startswith("https://huggingface.co/"):
        if "/blob/" in model_url:
            model_url = model_url.replace("/blob/", "/resolve/")
        huggingface_token ="YOUR_HUGGINGFACE_TOKEN" # 自分のトークンに変更
        user_header = f'"Authorization: Bearer {huggingface_token}"'
        # !aria2c --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -s 16 -k 1M {model_url} -d /content/automatic/models/Stable-diffusion -o {base_name}
    else:
        # !aria2c --console-log-level=error --summary-interval=10 -c -x 16 -k 1M -s 16 -d /content/automatic/models/Stable-diffusion {model_url}

install(model_url)
# Out:
#  *** Download Progress Summary as of Wed Jul 19 22:03:10 2023 ***
# =
# [#321a6b 1.6GiB/3.9GiB(41%) CN:16 DL:167MiB ETA:14s]
# FILE: /content/automatic/models/Stable-diffusion/7th_anime_v3_A.safetensors
# -
#
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 321a6b|OK  |   199MiB/s|/content/automatic/models/Stable-diffusion/7th_anime_v3_A.safetensors
#
# Status Legend:
# (OK):download completed.

# %%
#@title 3.VAE
import os

vae_name = "kl-f8-anime" #@param ["vae-ft-mse-840000-ema-pruned","vae-ft-mse-560000-ema-pruned","kl-f8-anime","kl-f8-anime2","Anything-V3.0.vae.pt","anything-v4.0.vae.pt","autoencoder_fix_kl-f8-trinart_characters","orangemix.vae.pt"] {allow-input: false}

url_dict = {
    "vae-ft-mse-840000-ema-pruned": "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors",
    "vae-ft-mse-560000-ema-pruned": "https://huggingface.co/stabilityai/sd-vae-ft-ema-original/resolve/main/vae-ft-ema-560000-ema-pruned.ckpt",
    "kl-f8-anime": "https://huggingface.co/hakurei/waifu-diffusion-v1-4/resolve/main/vae/kl-f8-anime.ckpt",
    "kl-f8-anime2": "https://huggingface.co/hakurei/waifu-diffusion-v1-4/resolve/main/vae/kl-f8-anime2.ckpt",
    "Anything-V3.0.vae.pt": "https://huggingface.co/ckpt/anything-v3.0/resolve/main/Anything-V3.0.vae.pt",
    "anything-v4.0.vae.pt":"https://huggingface.co/andite/anything-v4.0/resolve/main/anything-v4.0.vae.pt",
    "autoencoder_fix_kl-f8-trinart_characters": "https://huggingface.co/naclbit/trinart_characters_19.2m_stable_diffusion_v1/resolve/main/autoencoder_fix_kl-f8-trinart_characters.ckpt",
    "orangemix.vae.pt": "https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/VAEs/orangemix.vae.pt",
}

vae_url = url_dict.get(vae_name)

def install(vae_url):
    base_name = os.path.basename(vae_url)
    # !aria2c --console-log-level=error --summary-interval=10 -c -x 16 -k 1M -s 16 {vae_url} -d /content/automatic/models/VAE -o {base_name}

    print(base_name)

install(vae_url)
# Out:
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# ac89f7|OK  |   168MiB/s|/content/automatic/models/VAE/kl-f8-anime.ckpt
#
# Status Legend:
# (OK):download completed.
# kl-f8-anime.ckpt

# %%
#@title xformers
# !pip install torch==2.0.1
# !pip install -U xformers

# %%
#@title 4.Vladmandic webuiの起動
# %cd /content/automatic
# !python launch.py --no-hashing --share --upgrade --skip-extensions
# Out:
# /content/automatic
# 22:03:25-433261 INFO     Starting SD.Next
# 22:03:25-438175 INFO     Python 3.10.6 on Linux
# 22:03:25-447021 INFO     Version: dafd9500 Wed Jul 19 15:38:17 2023 -0500
# 22:03:25-766942 INFO     Updating main repository
# 22:03:26-171504 INFO     Upgraded to version: dafd9500 Wed Jul 19 15:38:17 2023
#                          -0500
# 22:03:26-175279 INFO     nVidia CUDA toolkit detected
# 22:03:26-178062 WARNING  Not used, uninstalling: xformers 0.0.20
# 22:03:27-538736 INFO     Verifying requirements
# 22:03:27-541235 INFO     Installing package: addict
# 22:03:34-180604 INFO     Installing package: aenum
# 22:03:39-440328 INFO     Installing package: bitsandbytes
# 22:03:50-340760 INFO     Installing package: blendmodes
# 22:03:56-993889 INFO     Installing package: clean-fid
# 22:04:02-945374 INFO     Installing package: easydev
# 22:04:09-014645 INFO     Installing package: extcolors
# 22:04:13-937018 INFO     Installing package: facexlib
# 22:04:20-794185 INFO     Installing package: filetype
# 22:04:25-758705 INFO     Installing package: gfpgan
# 22:04:36-932487 INFO     Installing package: GitPython
# 22:04:42-877185 INFO     Installing package: httpcore
# 22:04:48-332603 INFO     Installing package: inflection
# 22:04:52-968893 INFO     Installing package: jsonmerge
# 22:04:59-402872 INFO     Installing package: kornia
# 22:05:04-745206 INFO     Installing package: lark
# 22:05:09-761675 INFO     Installing package: lmdb
# 22:05:15-903723 INFO     Installing package: lpips
# 22:05:21-994309 INFO     Installing package: omegaconf
# 22:05:30-721751 INFO     Installing package: open-clip-torch
# 22:05:38-036625 INFO     Installing package: piexif
# 22:05:44-969853 INFO     Installing package: realesrgan
# 22:05:50-245343 INFO     Installing package: resize-right
# 22:05:55-512504 INFO     Installing package: safetensors
# 22:06:01-752346 INFO     Installing package: tb_nightly
# 22:06:07-712265 INFO     Installing package: torchdiffeq
# 22:06:14-728584 INFO     Installing package: torchsde
# 22:06:19-954575 INFO     Installing package: voluptuous
# 22:06:24-904638 INFO     Installing package: yapf
# 22:06:31-464987 INFO     Installing package: basicsr
# 22:06:36-387161 INFO     Installing package: compel
# 22:06:51-882272 INFO     Installing package: fasteners
# 22:06:58-774871 WARNING  Package wrong version: pyarrow 9.0.0 required 11.0.0
# 22:06:58-777213 INFO     Installing package: pyarrow==11.0.0
# 22:07:09-736867 INFO     Installing package: antlr4-python3-runtime==4.9.3
# 22:07:16-746807 WARNING  Package wrong version: requests 2.27.1 required 2.31.0
# 22:07:16-749182 INFO     Installing package: requests==2.31.0
# 22:07:23-425387 INFO     Installing package: accelerate==0.20.3
# 22:07:29-229831 INFO     Installing package: diffusers==0.18.2
# 22:07:37-576725 INFO     Installing package: einops==0.4.1
# 22:07:43-002130 INFO     Installing package: gradio==3.32.0
# 22:08:02-515737 WARNING  Package wrong version: numpy 1.22.4 required 1.23.5
# 22:08:02-517379 INFO     Installing package: numpy==1.23.5
# 22:08:15-123412 WARNING  Package wrong version: numba 0.56.4 required 0.57.0
# 22:08:15-125986 INFO     Installing package: numba==0.57.0
# 22:08:29-757661 INFO     Installing package: pytorch_lightning==1.9.4
# 22:08:40-077764 INFO     Installing package: transformers==4.30.2
# 22:08:55-382568 INFO     Installing package: tomesd==0.1.3
# 22:09:01-619656 WARNING  Package wrong version: urllib3 1.26.16 required 1.26.15
# 22:09:01-621289 INFO     Installing package: urllib3==1.26.15
# 22:09:08-433006 WARNING  Package wrong version: Pillow 8.4.0 required 9.5.0
# 22:09:08-435346 INFO     Installing package: Pillow==9.5.0
# 22:09:17-907784 INFO     Installing package: timm==0.6.13
# 22:09:24-512150 INFO     Verifying packages
# 22:09:24-513670 INFO     Installing package:
#                          git+https://github.com/openai/CLIP.git
# 22:09:36-190263 INFO     Installing package:
#                          git+https://github.com/patrickvonplaten/invisible-water
#                          mark.git@remove_onnxruntime_depedency
# 22:09:43-820233 INFO     Installing package: pi-heif
# 22:09:52-556575 INFO     Verifying repositories
# 22:09:52-558807 INFO     Cloning repository:
#                          https://github.com/Stability-AI/stablediffusion.git
# 22:09:55-680146 INFO     Cloning repository:
#                          https://github.com/CompVis/taming-transformers.git
# 22:10:08-090994 INFO     Cloning repository:
#                          https://github.com/crowsonkb/k-diffusion.git
# 22:10:09-063809 INFO     Cloning repository:
#                          https://github.com/sczhou/CodeFormer.git
# 22:10:10-301215 INFO     Cloning repository:
#                          https://github.com/salesforce/BLIP.git
# 22:10:11-189133 INFO     Verifying submodules
# 22:10:11-239129 ERROR    Error running git: None / submodule
# 22:10:11-241539 WARNING  Attempting repository recover
# 22:10:11-565800 ERROR    Error running git: None / submodule
# 22:10:11-568177 INFO     Continuing setup
# 22:10:11-607377 ERROR    Error running git: None / submodule --quiet update
#                          --init --recursive
# 22:10:12-547282 ERROR    Error updating submodule:
# 22:10:12-550407 ERROR    Error updating submodule: fatal: no submodule mapping
#                          found in .gitmodules for path
#                          'extensions-builtin/sd-extension-aesthetic-scorer'
# 22:10:20-490214 INFO     Extensions enabled: ['sd-webui-model-converter',
#                          'ScuNET', 'sd-webui-controlnet',
#                          'stable-diffusion-webui-rembg',
#                          'clip-interrogator-ext', 'SwinIR',
#                          'a1111-sd-webui-lycoris', 'Lora', 'LDSR',
#                          'stable-diffusion-webui-images-browser',
#                          'sd-extension-aesthetic-scorer',
#                          'sd-dynamic-thresholding', 'seed_travel',
#                          'sd-extension-system-info', 'prompt-bracket-checker',
#                          'sd-extension-steps-animation',
#                          'multidiffusion-upscaler-for-automatic1111']
# 22:10:20-494280 INFO     Verifying packages
# 22:10:20-496824 INFO     Updating Wiki
# 22:10:20-720512 WARNING  Setup complete with errors: 3
# 22:10:20-723886 WARNING  See log file for more details:
#                          /content/automatic/sdnext.log
# 22:10:20-738888 INFO     Extension preload: 0.0s
#                          /content/automatic/extensions-builtin
# 22:10:20-741512 INFO     Extension preload: 0.0s /content/automatic/extensions
# 22:10:20-766130 INFO     Server arguments: ['--no-hashing', '--share',
#                          '--upgrade', '--skip-extensions']
# No module 'xformers'. Proceeding without it.
# 22:10:38-968739 INFO     Pipeline: Backend.ORIGINAL
# 22:10:40-289883 INFO     Libraries loaded
# 22:10:40-292150 INFO     Using data path: /content/automatic
# 22:10:40-295076 INFO     Available VAEs: /content/automatic/models/VAE 1
# 22:10:40-309090 INFO     Available models:
#                          /content/automatic/models/Stable-diffusion 1
# 22:10:42-138629 INFO     Loading UI theme: name=black-orange style=Auto
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://e13956824da0d9a375.gradio.live
# 22:10:51-605415 INFO     Local URL: http://127.0.0.1:7860/
# 22:10:51-607572 INFO     Share URL: https://e13956824da0d9a375.gradio.live
# 22:10:51-609046 INFO     Initializing middleware
# 22:10:51-739305 INFO     Model metadata saved: /content/automatic/metadata.json
#                          1
# 22:10:51-742107 WARNING  Selected checkpoint not found: model.ckpt
# Loading weights: /content/automatic/models/Stable-diffusion/7th_anime_v3_A.saf…
# 22:10:53-894674 INFO     Setting Torch parameters: dtype=torch.float16
#                          vae=torch.float16 unet=torch.float16
# LatentDiffusion: Running in eps-prediction mode
# DiffusionWrapper has 859.52 M params.
# Downloading (…)olve/main/vocab.json: 100% 961k/961k [00:00<00:00, 10.6MB/s]
# Downloading (…)olve/main/merges.txt: 100% 525k/525k [00:00<00:00, 19.1MB/s]
# Downloading (…)cial_tokens_map.json: 100% 389/389 [00:00<00:00, 1.73MB/s]
# Downloading (…)okenizer_config.json: 100% 905/905 [00:00<00:00, 4.64MB/s]
# Downloading (…)lve/main/config.json: 100% 4.52k/4.52k [00:00<00:00, 17.2MB/s]
# 22:11:15-864039 INFO     Applying scaled dot product cross attention
#                          optimization
# 22:11:15-987042 INFO     Embeddings: loaded=0 skipped=0
# 22:11:15-993298 INFO     Model loaded in 23.9s (load=1.7s config=0.1s
#                          create=1.9s apply=18.0s vae=1.3s move=0.6s
#                          embeddings=0.1s)
# 22:11:16-378877 INFO     Model load finished: {'ram': {'used': 7.34, 'total':
#                          12.68}, 'gpu': {'used': 2.15, 'total': 14.75},
#                          'retries': 0, 'oom': 0} cached=0
# 22:11:16-857682 INFO     Startup time: 56.1s (torch=14.7s gradio=1.0s
#                          libraries=3.9s codeformer=0.1s scripts=1.7s
#                          onchange=0.1s ui-txt2img=0.1s ui-img2img=0.1s
#                          ui-settings=0.3s ui-defaults=0.1s launch=8.8s
#                          app-started=0.1s checkpoint=25.1s)

# %% [markdown]
# - https://huggingface.co/JCTN/sd-vae-ft-mse-original
